# %%
import pandas as pd

df = pd.read_csv("C:\pydata\iris.csv", sep = ",")
df
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# 5             6           5.4          3.9           1.7          0.4
# 6             7           4.6          3.4           1.4          0.3
# 7             8           5.0          3.4           1.5          0.2
# 8             9           4.4          2.9           1.4          0.2
# 9            10           4.9          3.1           1.5          0.1
# 10           11           5.4          3.7           1.5          0.2
# 11           12           4.8          3.4           1.6          0.2
# ...

# %%
df[df['Species']=='setosa']
# Out:
#     Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0            1           5.1          3.5           1.4          0.2  setosa
# 1            2           4.9          3.0           1.4          0.2  setosa
# 2            3           4.7          3.2           1.3          0.2  setosa
# 3            4           4.6          3.1           1.5          0.2  setosa
# 4            5           5.0          3.6           1.4          0.2  setosa
# 5            6           5.4          3.9           1.7          0.4  setosa
# 6            7           4.6          3.4           1.4          0.3  setosa
# 7            8           5.0          3.4           1.5          0.2  setosa
# 8            9           4.4          2.9           1.4          0.2  setosa
# 9           10           4.9          3.1           1.5          0.1  setosa
# 10          11           5.4          3.7           1.5          0.2  setosa
# ...

# %%
import numpy as np

f1 = np.linspace(1,10,5)

# %%
f1
# Out:
# array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ])

# %%
import json
json_str = """{"name":"Field", "height":6.0, "weight":3,\
"properties":{"code":111, "name": ""}}"""
my_obj = json.loads(json_str)
my_obj
# Out:
# {'name': 'Field',
#  'height': 6.0,
#  'weight': 3,
#  'properties': {'code': 111, 'name': ''}}

# %%
import json

fname = "C:/pydata/test.json"
f= open(fname).read()
my_jsonf_obj = json.loads(f)
my_jsonf_obj
# Out:
# {'관리기관명': '관악구청',
#  '소재지도로명주소': '서울특별시 관악구 난향7길 42',
#  '소재지지번주소': '서울특별시 관악구 난향동 675-312',
#  '설치목적구분': '다목적',
#  '카메라대수': '1',
#  '카메라화소수': '200',
#  '촬영방면정보': '반경 30~150미터 이내(기종따라 다름)',
#  '보관일수': '30',
#  '설치년월': '2015-01',
#  '관리기관전화번호': '02-879-5832',
#  '위도': '37.46071529',
#  '경도': '126.9153562',
#  '데이터기준일자': '2018-02-13',
#  '제공기관코드': '3200000',
#  '제공기관명': '서울특별시 관악구'}

# %%
from html.parser import HTMLParser
import urllib.request

TOPIC = "Decision_tree" #검색핳 단어를 입력
url = "https://en.wikipedia.org/wiki/%s" % TOPIC  # %s 는 str을 부른다
class LinkCountingParser(HTMLParser):
    in_paragraph = False
    link_count = 0
    def handle_starttag(self,tag,attrs):
        if tag=='p':
            self.in_paragraph = True
        elif tag=='a' and self.in_paragraph:
                self.link_count += 1
    def handle_endtag(self, tag):
        if tag=='p':
            self.in_paragraph = False
html = urllib.request.urlopen(url).read()
html = html.decode('utf-8')
parser = LinkCountingParser()
parser.feed(html)
print("there were", parser.link_count, "links in the article")
# Out:
# there were 42 links in the article

# %%
# 당뇨병 예측하기
import sklearn.datasets
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import normalize
from sklearn.metrics import r2_score
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# data load
diabetes = sklearn.datasets.load_diabetes()
# normalize
X,Y = normalize(diabetes['data']), diabetes['target']
# train set, test set
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size =.8)
# regression model
linear = LinearRegression()
linear.fit(X_train, Y_train)
# predict
preds_linear = linear.predict(X_test)
# get correlation
corr_linear = round(pd.Series(preds_linear).corr(pd.Series(Y_test)), 3)
# get R2
rsquared_linear = r2_score(Y_test, preds_linear)

# %%
import sklearn.datasets
# data load
diabetes = sklearn.datasets.load_diabetes()
print(diabetes)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]]), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
diabetes = sklearn.datasets.load_diabetes()
import pandas as pd
df = pd.DataFrame(diabetes['data'])
df.head()

df.rename(columns ={df.columns[0]: 'AGE'}, inplace =True)
df.rename(columns ={df.columns[1]: 'SEX'}, inplace =True)
df.rename(columns ={df.columns[2]: 'BMI'}, inplace =True)
df.rename(columns ={df.columns[3]: 'BP'}, inplace =True)
df.rename(columns ={df.columns[4]: 'S1'}, inplace =True)
df.rename(columns ={df.columns[5]: 'S2'}, inplace =True)
df.rename(columns ={df.columns[6]: 'S3'}, inplace =True)
df.rename(columns ={df.columns[7]: 'S4'}, inplace =True)
df.rename(columns ={df.columns[8]: 'S5'}, inplace =True)
df.rename(columns ={df.columns[9]: 'Y'}, inplace =True)
# Out:
# 1   -0.051474
# 2    0.044451
# Name: BMI, dtype: float64

# %%
# normalize
X,Y = normalize(diabetes['data']), diabetes['target']
print(X)
print(Y)
# Out:
# [[ 0.32100597  0.42726811  0.52014127 ... -0.02185454  0.16784162
#   -0.14876892]
#  [-0.01166166 -0.27661579 -0.31895198 ... -0.24471534 -0.4233959
#   -0.57132977]
#  [ 0.6574065   0.39059633  0.34258958 ... -0.0199788   0.02207134
#   -0.1998475 ]
#  ...
#  [ 0.42500219  0.51642207 -0.1620822  ... -0.11289848 -0.47769422
#    0.15784799]
#  [-0.4486945  -0.44049627  0.38544135 ...  0.26207406  0.43937866
#   -0.25586467]
#  [-0.19283439 -0.18931106 -0.30969841 ... -0.16747894 -0.01789509
#    0.01299519]]
# [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
#   52.  37. 170. 170.  61. 144.  52. 128.  71. 163. 150.  97. 160. 178.
#   48. 270. 202. 111.  85.  42. 170. 200. 252. 113. 143.  51.  52. 210.
# ...

# %%
# train set, test set
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, train_size=.8)
print(len(X_train))
print(len(Y_train))
print(len(X_test))
print(len(Y_test))
# Out:
# 353
# 353
# 89
# 89

# %%
# regression model
linear = LinearRegression()
print(linear)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# predict
linear.fit(X_train, Y_train)   #X, Y 트레인을 이용해서 fitting 을 해서 
preds_linear = linear.predict(X_test)   #X 테스트로 예측을 해보는 거
print(preds_linear)
# Out:
# [223.12961094  80.34297676 123.7498274  106.61979655 141.67326031
#  262.67334079 113.36714057 237.59187564 102.61493853  65.92485239
#  223.24218842  85.25534694  93.59634422 112.50925677 224.93835385
#   93.11645033  57.19084912 116.22043635 173.97598129 144.74179355
#  122.69725375 162.93056266 143.73948674 153.68589185 163.94955654
#  159.50430601  84.35516023 157.88101887 133.71303596 194.24225797
#  256.56491486  85.07642077 180.12432753 102.20854173 162.52881922
#  154.74703565 242.95739029 225.40798131 180.83991378 224.29724572
#   70.32009    135.47063178 222.66411615 104.5487086  140.00660687
#  193.32269239  74.24260553 224.60472719 236.71783494  85.88879962
#   79.40428445 119.6055246  221.64135509 149.59821443 156.45578808
#  176.09963229 179.34846632 110.92935463 122.55015216 134.05022314
#   78.68158619 175.78841423 134.06704969 183.92546357  50.63384838
#  189.5348129  125.22734568 252.13729895 203.99749548  79.09489199
# ...

# %%
# correlation
corr_linear = round(pd.Series(preds_linear).corr(pd.Series(Y_test)), 3)
print(corr_linear)

# get R2
rsquared_linear = r2_score(preds_linear, Y_test)
print(rsquared_linear)
# Out:
# 0.713
# 0.03888092743364435

# %%
print("Linear coefficients")
print(linear.coef_)
print(linear.intercept_)
plt.scatter(preds_linear, Y_test)
plt.title("Lin. Reg. Corr=%f Rsq=%f (corr_linear, rsquared_linear)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.plot(Y_test, Y_test, 'k--')  #어딘가 이상함

plt.show()
# Out:
# Linear coefficients
# [ -3.07454541 -31.27558297  70.52397138  49.71656209 -31.7651433
#   -0.45271331 -11.94383906  36.36219494  77.31667694  18.30874235]
# 155.27607794192903

# %%
import pandas as pd

CCTV_Seoul = pd.read_csv('C:/pydata/CCTV_in_Seoul.csv', encoding = 'utf-8')

CCTV_Seoul.head()
CCTV_Seoul.columns
CCTV_Seoul.columns[0]

CCTV_Seoul.rename(columns={CCTV_Seoul.columns[0]:'구별'}, inplace = True)
CCTV_Seoul.head()
CCTV_Seoul.sort_values(by='소계',ascending=True).head(5)

CCTV_Seoul.sort_values(by='소계',ascending=False).head(5)

CCTV_Seoul['최근증가율'] = (CCTV_Seoul['2016년']+ CCTV_Seoul['2015년']+\
                      CCTV_Seoul['2014년'])/ CCTV_Seoul['2013년도 이전']*100
CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head(5)
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22  종로구  1002        464    314    211    630  248.922414
# 9   도봉구   485        238    159     42    386  246.638655
# 12  마포구   574        314    118    169    379  212.101911
# 8   노원구  1265        542     57    451    516  188.929889
# 1   강동구   773        379     99    155    377  166.490765

# %%
import pandas as pd

pop_Seoul = pd.read_excel('C:/pydata/population_in_Seoul.xls',
                         header = 2,
                         encoding = 'utf-8')
pop_Seoul.head()
pop_Seoul.rename(columns ={pop_Seoul.columns[0]: '구별',
                          pop_Seoul.columns[1]: '인구수',
                          pop_Seoul.columns[2]: '한국인',
                          pop_Seoul.columns[3]: '외국인',
                          pop_Seoul.columns[4]: '고령자'}, inplace = True)
pop_Seoul.head()
pop_Seoul.drop([0], inplace = True)
pop_Seoul.head()

pop_Seoul['구별'].unique()

pop_Seoul['외국인비율'] = pop_Seoul['외국인']/ pop_Seoul['인구수']*100
pop_Seoul['고령자비율'] = pop_Seoul['고령자']/ pop_Seoul['인구수']*100
pop_Seoul.head()

pop_Seoul.sort_values(by='인구수', ascending =False).head(5)
pop_Seoul.sort_values(by='외국인', ascending =False).head(5)
pop_Seoul.sort_values(by='외국인비율', ascending =False).head(5)
pop_Seoul.sort_values(by='고령자', ascending =False).head(5)
pop_Seoul.sort_values(by='고령자비율', ascending =False).head(5)
# Out:
#       구별     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 9    강북구  330192  326686   3506  54813  1.061806  16.600342
# 1    종로구  162820  153589   9231  25425  5.669451  15.615404
# 2     중구  133240  124312   8928  20764  6.700690  15.583909
# 3    용산구  244203  229456  14747  36231  6.038828  14.836427
# 13  서대문구  327163  314982  12181  48161  3.723221  14.720797

# %%
import pandas as pd
import numpy as np

data_result = pd.merge(CCTV_Seoul, pop_Seoul, on = '구별')
data_result.head()

del data_result['2013년도 이전']
del data_result['2014년']
del data_result['2015년']
del data_result['2016년']
data_result.head()

data_result.set_index('구별', inplace = True)
data_result.head()

np.corrcoef(data_result['고령자비율'], data_result['소계'])
np.corrcoef(data_result['외국인비율'], data_result['소계'])
np.corrcoef(data_result['인구수'], data_result['소계'])
data_result.sort_values(by='소계', ascending = False).head(5)
data_result.sort_values(by='인구수', ascending = False).head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-635488d08589> in <module>()
#       2 import numpy as np
#       3
# ----> 4 data_result = pd.merge(CCTV_Seoul, pop_Seoul, on = '구별')
#       5 data_result.head()
#       6
#
# NameError: name 'CCTV_Seoul' is not defined

# %%
dk =
# Out:
# array([[1.        , 0.30634228],
#        [0.30634228, 1.        ]])

# %%
import platform
from matplotlib import pyplot as plt
from matplotlib import font_manager, rc
#그래프에서 마이너스 폰트가 깨지는 문제에 대한 대처
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font',family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...')

# %%
data_result.head() #cctv와 인구데이터 시각화
# Out:
#        소계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 강남구  2780  150.619195  570500  565550   4950  63167  0.867660  11.072217
# 강동구   773  166.490765  453233  449019   4214  54622  0.929765  12.051638
# 강북구   748  125.203252  330192  326686   3506  54813  1.061806  16.600342
# 강서구   884  134.793814  603772  597248   6524  72548  1.080540  12.015794
# 관악구  1496  149.290780  525515  507203  18312  68082  3.484582  12.955291

# %%
plt.figure()
data_result['소계'].plot(kind='barh', grid=True,
                      figsize=(10,10))
plt.show()

# %%
data_result['소계'].sort_values().plot(kind='barh',
                                    grid=True, figsize=(10,10))
plt.show()

# %%
data_result['CCTV비율'] = data_result['소계']/data_result['인구수']*100

data_result['CCTV비율'].sort_values().plot(kind='barh',
                                        grid = True, figsize=(10,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de07a5351282> in <module>()
# ----> 1 data_result['CCTV비율'] = data_result['소계']/data_result['인구수']*100
#       2
#       3 data_result['CCTV비율'].sort_values().plot(kind='barh',
#       4                                         grid = True, figsize=(10,10))
#       5 plt.show()
#
# NameError: name 'data_result' is not defined

# %%
plt.figure(figsize=(6,6))
plt.scatter(data_result['인구수'], data_result['소계'], s= 55)
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
import platform
from matplotlib import pyplot as plt
from matplotlib import font_manager, rc

fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

data_result['오차'] = np.abs(data_result['소계'] - f1(data_result['인구수']))

df_sort = data_result.sort_values(by='오차', ascending = False)
df_sort.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-e5ec4a7380fc> in <module>()
#       3 from matplotlib import font_manager, rc
#       4
# ----> 5 fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)
#       6
#       7 f1 = np.poly1d(fp1)
#
# NameError: name 'np' is not defined

# %%
plt.figure(figsize=(14,10))
plt.scatter(data_result['인구수'], data_result['소계'],
           c = data_result['오차'], s=50) #점크기
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='R') #ls: 선모양, lw:선두께

for n in range(10):
    plt.text(df_sort['인구수'][n]*1.02, df_sort['소계'][n]*0.98,
            df_sort.index[n], fontsize= 15)

plt.xlabel('인구수')
plt.ylabel('인구당비율')
plt.colorbar()
plt.grid()
plt.show()

# %%
from bs4 import BeautifulSoup

page = open("C:/pydata/test.html", 'r').read()
soup = BeautifulSoup(page,'html.parser')
print(soup.prettify())                        # 이쁘게 보기
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
list(html.children)
body = list(html.children)[3]
body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
list(body.children)

len(list(body.children))

soup.find_all('p')

soup.find_all('p', class_='outer-text')

soup.find_all(class_='outer-text')

soup.find_all(id="first")
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
list(soup.children)

soup.head

soup.head.next_sibling


soup.head.previous_sibling

soup.head.next_sibling.next_sibling

body.p
body.p.next_sibling
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
